# %% [markdown]
# <a href="https://colab.research.google.com/github/agdev/Routing/blob/main/Routing_Comparison_Finetuned_vs_Semantic_Router.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Installing dependencies**

# %%
# !pip install datasets --quiet
# !pip install transformers --quiet
# !pip install transformers[torch] --quiet
# !pip install -qU semantic-router
# !pip install evaluate --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.7 MB/s eta 0:00:00

# %% [markdown]
# # **Importing**

# %%
from datasets import load_dataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Load dataset**

# %%
dataset_name = "bitext/Bitext-customer-support-llm-chatbot-training-dataset"
# Load the dataset
base_ds = load_dataset(dataset_name, split="train")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/11.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/19.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/26872 [00:00<?, ? examples/s]

# %%
base_df = base_ds.to_pandas()
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26872 entries, 0 to 26871
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flags        26872 non-null  object
#  1   instruction  26872 non-null  object
#  2   category     26872 non-null  object
#  3   intent       26872 non-null  object
#  4   response     26872 non-null  object
# dtypes: object(5)
# memory usage: 1.0+ MB

# %%
base_df.head()
# Out:
#    flags                                        instruction category  \
# 0      B   question about cancelling order {{Order Number}}    ORDER
# 1    BQZ  i have a question about cancelling oorder {{Or...    ORDER
# 2   BLQZ    i need help cancelling puchase {{Order Number}}    ORDER
# 3     BL         I need to cancel purchase {{Order Number}}    ORDER
# 4  BCELN  I cannot afford this order, cancel purchase {{...    ORDER
#
#          intent                                           response
# 0  cancel_order  I've understood you have a question regarding ...
# 1  cancel_order  I've been informed that you have a question ab...
# 2  cancel_order  I can sense that you're seeking assistance wit...
# 3  cancel_order  I understood that you need assistance with can...
# 4  cancel_order  I'm sensitive to the fact that you're facing f...

# %%
base_df['category'].unique()
# Out:
# array(['ORDER', 'SHIPPING', 'CANCEL', 'INVOICE', 'PAYMENT', 'REFUND',
#        'FEEDBACK', 'CONTACT', 'ACCOUNT', 'DELIVERY', 'SUBSCRIPTION'],
#       dtype=object)

# %%
train_df, test_df = train_test_split(base_df, test_size=0.2, random_state=42)

# %% [markdown]
# # **Init Semantic Router**

# %%
from semantic_router import Route
from pandas import DataFrame
CATEGORY_COL: str = "category"
INSTRUCTION_COL: str = "instruction"

def create_routes(df: DataFrame, groupby_col: str):
  grouped = df.groupby(groupby_col)
  rts = []
  for category, group in grouped:
    rts.append(Route(name = category, utterances = group[INSTRUCTION_COL].tolist()))
  return rts

routes = create_routes(train_df, CATEGORY_COL)
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %% [markdown]
# # **Init Encoder**

# %%
import os
from getpass import getpass
from semantic_router.encoders import HuggingFaceEncoder

from google.colab import userdata
hf_key = userdata.get('HuggingFace')

os.environ["HUGGINGFACE_API_KEY"] = hf_key or getpass(
    "Enter Hugging Face API Key: "
)

encoder = HuggingFaceEncoder()
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %% [markdown]
# # **Init RouterLayer**

# %%
from semantic_router.layer import RouteLayer

rl = RouteLayer(encoder=encoder, routes=routes)

# %% [markdown]
# # **Define Testing Inputs**

# %%
# text_samples = [
#     "I reqeust immediate refund",
#     "I was billed incorrectly",
#     "Where do I leave a tip",
#     "Not worth the money, would not buy again. I want to cancel order.",
#     "I would like to speak with the manager"
# ]
import io
# Test data generated by LLM
csv_data = """Text,Category
"Can you expedite my shipping? I need the item urgently.","SHIPPING"
"I'd like to cancel my subscription. How do I do that?","SUBSCRIPTION"
"The product I received is damaged. I want a full refund.","REFUND"
"How can I update my billing information for future orders?","PAYMENT"
"I never received an invoice for my last purchase. Can you send it?","INVOICE"
"Your delivery person was extremely rude. I want to file a complaint.","FEEDBACK"
"I accidentally placed two identical orders. Please cancel one of them.","CANCEL"
"What's the status of my order? It's been a week and I haven't received any updates.","ORDER"
"How do I change the delivery address for my upcoming shipment?","DELIVERY"
"I forgot my account password. Can you help me reset it?","ACCOUNT"
"I'd like to speak with a customer service representative about my recent experience.","CONTACT"
"Can I get a copy of my payment receipt for tax purposes?","INVOICE"
"Your website charged me twice for the same item. Please fix this and refund me.","PAYMENT"
"I want to leave a positive review for the excellent service I received. Where can I do that?","FEEDBACK"
"My package was supposed to arrive yesterday but it's still not here. What's going on?","SHIPPING"
"How do I cancel my recurring monthly subscription?","SUBSCRIPTION"
"I received the wrong item in my order. What's the return process?","ORDER"
"Can you provide me with the contact information for your corporate office?","CONTACT"
"I'd like to change the payment method associated with my account.","ACCOUNT"
"The refund I was promised hasn't shown up in my bank account yet. Please look into this.","REFUND"
"Is it possible to get same-day delivery for my order?","DELIVERY"
"I'm having trouble accessing my online account. Can someone assist me?","ACCOUNT"
"Your product arrived late and now I don't need it. I want to return it for a full refund.","CANCEL"
"How long does it typically take for a refund to be processed?","REFUND"
"Can I get an itemized invoice for my last three orders?","INVOICE"
"""
# Using io.StringIO to simulate a file object
csv_file = io.StringIO(csv_data)

# Reading the CSV data into a DataFrame
text_samples_df = pd.read_csv(csv_file)
# print(text_samples_df.columns)
# Display the DataFrame
print(text_samples_df)
# Out:
# Index(['Text', 'Category'], dtype='object')
#                                                  Text      Category
# 0   Can you expedite my shipping? I need the item ...      SHIPPING
# 1   I'd like to cancel my subscription. How do I d...  SUBSCRIPTION
# 2   The product I received is damaged. I want a fu...        REFUND
# 3   How can I update my billing information for fu...       PAYMENT
# 4   I never received an invoice for my last purcha...       INVOICE
# 5   Your delivery person was extremely rude. I wan...      FEEDBACK
# 6   I accidentally placed two identical orders. Pl...        CANCEL
# 7   What's the status of my order? It's been a wee...         ORDER
# 8   How do I change the delivery address for my up...      DELIVERY
# 9   I forgot my account password. Can you help me ...       ACCOUNT
# 10  I'd like to speak with a customer service repr...       CONTACT
# 11  Can I get a copy of my payment receipt for tax...       INVOICE
# 12  Your website charged me twice for the same ite...       PAYMENT
# 13  I want to leave a positive review for the exce...      FEEDBACK
# 14  My package was supposed to arrive yesterday bu...      SHIPPING
# 15  How do I cancel my recurring monthly subscript...  SUBSCRIPTION
# 16  I received the wrong item in my order. What's ...         ORDER
# 17  Can you provide me with the contact informatio...       CONTACT
# 18  I'd like to change the payment method associat...       ACCOUNT
# 19  The refund I was promised hasn't shown up in m...        REFUND
# 20  Is it possible to get same-day delivery for my...      DELIVERY
# 21  I'm having trouble accessing my online account...       ACCOUNT
# 22  Your product arrived late and now I don't need...        CANCEL
# 23  How long does it typically take for a refund t...        REFUND
# 24  Can I get an itemized invoice for my last thre...       INVOICE

# %%
def get_navs(texts):
  navs = []
  for text in texts:
    navs.append(rl(text))
  return navs

# %%
from pprint import pprint

navs = get_navs(text_samples_df["Text"])

pprint(navs)
# Out:
# [RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name=None, function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name=None, function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None)]

# %%
# from transformers import AutoTokenizer
from huggingface_hub import login
login(token = hf_key, add_to_git_credential=True)

# # Load the tokenizer for ALBERT
# model_name: str = "vineetsharma/customer-support-intent-albert"
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# tokenizer.save_pretrained("AIEnthusiast369/customer-support-categ_classification-albert")
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# import os
# print(os.getcwd())
# Out:
# /content

# %% [markdown]
# # **Loading Model and Classfying data with Model **

# %%
import torch
def get_device():
  return torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# prompt: load this model "AIEnthusiast369/customer-support-categ_classification-albert" from hugging face and run the model to classify text_samples
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer, AutoConfig
import traceback
from huggingface_hub import hf_hub_download
from transformers import pipeline, Pipeline
from typing import Tuple, Dict

# classifier = pipeline(model="AIEnthusiast369/customer-support-categ_classification-albert")
# for text in text_samples:
#   print(classifier(text))

def load_pipeline(model_name: str)-> Tuple[Pipeline, Dict[str, int]]:
  classifier = None
  label2Id = None
  try:
      # model_name = "AIEnthusiast369/customer-support-categ_classification-albert"
      # # Use hf_hub_download with your token for private models
      # model_path = hf_hub_download(repo_id=model_name, filename='pytorch_model.bin', use_auth_token=hf_key)
      # tokenizer_path = hf_hub_download(repo_id=model_name, filename='tokenizer.json', use_auth_token=hf_key)

      model = AutoModelForSequenceClassification.from_pretrained(model_name)
      tokenizer = AutoTokenizer.from_pretrained(model_name)
      label2Id = model.config.label2id
      # Load the tokenizer for ALBERT
      classifier = pipeline("text-classification", model=model, tokenizer=tokenizer, device=get_device())

      # Load model directly
      # config = AutoConfig.from_pretrained(fine_tuned_model_name, revision="main")

      # tokenizer = AutoTokenizer.from_pretrained(fine_tuned_model_name, revision="main")
      # classifier = AutoModelForSequenceClassification.from_pretrained(fine_tuned_model_name, config=config,  revision="main")

      # classifier = pipeline(model="AIEnthusiast369/customer-support-categ_classification-albert")

      # num_labels = model.config.num_labels
      # print(f"Model is configured to classify {num_labels} labels.")
  except Exception as e:
      print(f"An error occurred: {e}")
      traceback.print_exc()

  return classifier, label2Id

# %%
fine_tuned_model_name: str ="AIEnthusiast369/customer-support-categ_classification-albert_v2"
base_model_name: str = "vineetsharma/customer-support-intent-albert"
classifier, label2Id= load_pipeline(fine_tuned_model_name)

# %%
def get_classifications(texts):
  classifications = []
  for text in texts:
    classifications.append(classifier(text))
  return classifications

# %%
classifications=get_classifications(text_samples_df["Text"])
pprint(classifications)
# Out:
# [[{'label': 'DELIVERY', 'score': 0.999439537525177}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9991925358772278}],
#  [{'label': 'REFUND', 'score': 0.9999253749847412}],
#  [{'label': 'ORDER', 'score': 0.8836795091629028}],
#  [{'label': 'INVOICE', 'score': 0.9998661279678345}],
#  [{'label': 'FEEDBACK', 'score': 0.9992051720619202}],
#  [{'label': 'ORDER', 'score': 0.9996504783630371}],
#  [{'label': 'ORDER', 'score': 0.9998818635940552}],
#  [{'label': 'SHIPPING', 'score': 0.9993603825569153}],
#  [{'label': 'ACCOUNT', 'score': 0.9999545812606812}],
#  [{'label': 'CONTACT', 'score': 0.9998041987419128}],
#  [{'label': 'PAYMENT', 'score': 0.9999163150787354}],
#  [{'label': 'REFUND', 'score': 0.9999079704284668}],
#  [{'label': 'FEEDBACK', 'score': 0.9998249411582947}],
#  [{'label': 'DELIVERY', 'score': 0.9997318387031555}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.99912029504776}],
#  [{'label': 'ORDER', 'score': 0.9998646974563599}],
#  [{'label': 'CONTACT', 'score': 0.9980757236480713}],
#  [{'label': 'PAYMENT', 'score': 0.9999145269393921}],
#  [{'label': 'REFUND', 'score': 0.7759966850280762}],
#  [{'label': 'DELIVERY', 'score': 0.9995912909507751}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'REFUND', 'score': 0.9998666048049927}],
#  [{'label': 'REFUND', 'score': 0.999929666519165}],
#  [{'label': 'INVOICE', 'score': 0.9998793601989746}]]

# %% [markdown]
# # **Combining data for better visual**

# %%
import pandas as pd

# Extracting label and score
classification_data = [(item[0]['label'], item[0]['score']) for item in classifications]

# df_text = pd.DataFrame(text_samples_df, columns=['Text'])
# Create a DataFrame for classifications
df_classifications = pd.DataFrame(classification_data, columns=['Model_Label', 'Model_Score'])

# Extracting the names
nav_data = [(nav.name, nav.similarity_score) for nav in navs]

# Create a DataFrame for NAVs
df_navs = pd.DataFrame(nav_data, columns=['NAV_Name', 'NAV_Similarity_Score'])

# Concatenate the DataFrames
combined_df = pd.concat([text_samples_df, df_classifications, df_navs], axis=1)
combined_df.columns = combined_df.columns.str.strip()
labels_df = pd.concat([text_samples_df['Category'], df_classifications['Model_Label'], df_navs['NAV_Name']], axis=1)
# Display the result
# print(combined_df)

print(labels_df)


# for i in range(len(text_samples)):
#   print(f"Text: {text_samples[i]}")
#   print(f"Classification: {classifications[i]}")
#   print(f"Navigation: {navs[i]}")
#   print("-" * 20)
# Out:
#         Category   Model_Label      NAV_Name
# 0       SHIPPING      DELIVERY      SHIPPING
# 1   SUBSCRIPTION  SUBSCRIPTION  SUBSCRIPTION
# 2         REFUND        REFUND        REFUND
# 3        PAYMENT         ORDER         ORDER
# 4        INVOICE       INVOICE       INVOICE
# 5       FEEDBACK      FEEDBACK      FEEDBACK
# 6         CANCEL         ORDER         ORDER
# 7          ORDER         ORDER      DELIVERY
# 8       DELIVERY      SHIPPING      SHIPPING
# 9        ACCOUNT       ACCOUNT       ACCOUNT
# 10       CONTACT       CONTACT       CONTACT
# 11       INVOICE       PAYMENT       INVOICE
# 12       PAYMENT        REFUND          None
# 13      FEEDBACK      FEEDBACK      FEEDBACK
# 14      SHIPPING      DELIVERY      DELIVERY
# 15  SUBSCRIPTION  SUBSCRIPTION  SUBSCRIPTION
# 16         ORDER         ORDER         ORDER
# 17       CONTACT       CONTACT      FEEDBACK
# 18       ACCOUNT       PAYMENT       PAYMENT
# 19        REFUND        REFUND        REFUND
# 20      DELIVERY      DELIVERY      DELIVERY
# 21       ACCOUNT       ACCOUNT       ACCOUNT
# 22        CANCEL        REFUND          None
# 23        REFUND        REFUND        REFUND
# 24       INVOICE       INVOICE       INVOICE

# %%
import evaluate

metric = evaluate.load("accuracy")

def compute_accuracy(predictions, labels):

    return metric.compute(predictions=predictions, references=labels)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
def convert_labels_2_ids(labels):
  ids = []
  for label in labels:
    if label in label2Id:
      ids.append(label2Id[label])
    else:
      ids.append(-1)

  return ids

# %% [markdown]
# # **Calculating Accuracy for LLM Generate data**

# %%
# print(combined_df.columns)
print(compute_accuracy(convert_labels_2_ids(combined_df['Model_Label']), convert_labels_2_ids(combined_df['Category'])))
print(compute_accuracy(convert_labels_2_ids(combined_df['NAV_Name']), convert_labels_2_ids(combined_df['Category'])))
# Out:
# {'accuracy': 0.64}
# {'accuracy': 0.64}

# %% [markdown]
# # **Predicting classifications for test data from dataset**

# %%
classifications_test=get_classifications(test_df["instruction"])

# %%
pprint(classifications_test)
# Out:
# Streaming output truncated to the last 5000 lines.
#  [{'label': 'SHIPPING', 'score': 0.9998818635940552}],
#  [{'label': 'ACCOUNT', 'score': 0.9999262094497681}],
#  [{'label': 'DELIVERY', 'score': 0.9997116923332214}],
#  [{'label': 'SHIPPING', 'score': 0.9998800754547119}],
#  [{'label': 'REFUND', 'score': 0.9999290704727173}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'FEEDBACK', 'score': 0.9998687505722046}],
#  [{'label': 'SHIPPING', 'score': 0.999881386756897}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'ACCOUNT', 'score': 0.9999583959579468}],
#  [{'label': 'CONTACT', 'score': 0.9998883008956909}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'DELIVERY', 'score': 0.9997408986091614}],
#  [{'label': 'INVOICE', 'score': 0.9999079704284668}],
#  [{'label': 'SHIPPING', 'score': 0.9998822212219238}],
#  [{'label': 'PAYMENT', 'score': 0.9999256134033203}],
#  [{'label': 'FEEDBACK', 'score': 0.9998370409011841}],
#  [{'label': 'FEEDBACK', 'score': 0.9998815059661865}],
#  [{'label': 'ORDER', 'score': 0.999913215637207}],
#  [{'label': 'ACCOUNT', 'score': 0.9999063014984131}],
#  [{'label': 'ORDER', 'score': 0.9999409914016724}],
#  [{'label': 'INVOICE', 'score': 0.9999147653579712}],
#  [{'label': 'CANCEL', 'score': 0.9998144507408142}],
#  [{'label': 'PAYMENT', 'score': 0.9999243021011353}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997932314872742}],
#  [{'label': 'PAYMENT', 'score': 0.9999241828918457}],
#  [{'label': 'DELIVERY', 'score': 0.9997435212135315}],
#  [{'label': 'REFUND', 'score': 0.9999181032180786}],
#  [{'label': 'FEEDBACK', 'score': 0.9998711347579956}],
#  [{'label': 'INVOICE', 'score': 0.9999129772186279}],
#  [{'label': 'CONTACT', 'score': 0.9998973608016968}],
#  [{'label': 'REFUND', 'score': 0.9999228715896606}],
#  [{'label': 'PAYMENT', 'score': 0.9999197721481323}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'INVOICE', 'score': 0.999910831451416}],
#  [{'label': 'ACCOUNT', 'score': 0.9999521970748901}],
#  [{'label': 'CONTACT', 'score': 0.9998859167098999}],
#  [{'label': 'FEEDBACK', 'score': 0.9998717308044434}],
#  [{'label': 'PAYMENT', 'score': 0.9999257326126099}],
#  [{'label': 'ORDER', 'score': 0.9999412298202515}],
#  [{'label': 'ACCOUNT', 'score': 0.9999524354934692}],
#  [{'label': 'CANCEL', 'score': 0.9998193383216858}],
#  [{'label': 'SHIPPING', 'score': 0.9998784065246582}],
#  [{'label': 'REFUND', 'score': 0.999915599822998}],
#  [{'label': 'ORDER', 'score': 0.9998816251754761}],
#  [{'label': 'REFUND', 'score': 0.9999299049377441}],
#  [{'label': 'ORDER', 'score': 0.9999351501464844}],
#  [{'label': 'CANCEL', 'score': 0.9998113512992859}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'ORDER', 'score': 0.9999411106109619}],
#  [{'label': 'FEEDBACK', 'score': 0.9998623132705688}],
#  [{'label': 'ACCOUNT', 'score': 0.9999562501907349}],
#  [{'label': 'ACCOUNT', 'score': 0.999954342842102}],
#  [{'label': 'ACCOUNT', 'score': 0.9999549388885498}],
#  [{'label': 'REFUND', 'score': 0.999913215637207}],
#  [{'label': 'ACCOUNT', 'score': 0.9999542236328125}],
#  [{'label': 'DELIVERY', 'score': 0.9997406601905823}],
#  [{'label': 'REFUND', 'score': 0.9999192953109741}],
#  [{'label': 'DELIVERY', 'score': 0.999739944934845}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'FEEDBACK', 'score': 0.9998759031295776}],
#  [{'label': 'INVOICE', 'score': 0.9999101161956787}],
#  [{'label': 'ACCOUNT', 'score': 0.9999539852142334}],
#  [{'label': 'ORDER', 'score': 0.9999415874481201}],
#  [{'label': 'FEEDBACK', 'score': 0.9998615980148315}],
#  [{'label': 'REFUND', 'score': 0.9999285936355591}],
#  [{'label': 'ORDER', 'score': 0.9999399185180664}],
#  [{'label': 'ACCOUNT', 'score': 0.9999492168426514}],
#  [{'label': 'INVOICE', 'score': 0.999913215637207}],
#  [{'label': 'INVOICE', 'score': 0.9999052286148071}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'FEEDBACK', 'score': 0.9998688697814941}],
#  [{'label': 'ORDER', 'score': 0.9999425411224365}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'PAYMENT', 'score': 0.9999269247055054}],
#  [{'label': 'CONTACT', 'score': 0.9998949766159058}],
#  [{'label': 'PAYMENT', 'score': 0.9999270439147949}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'DELIVERY', 'score': 0.9997444748878479}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'DELIVERY', 'score': 0.9997445940971375}],
#  [{'label': 'REFUND', 'score': 0.9999103546142578}],
#  [{'label': 'ORDER', 'score': 0.9999366998672485}],
#  [{'label': 'ORDER', 'score': 0.9999420642852783}],
#  [{'label': 'INVOICE', 'score': 0.9999171495437622}],
#  [{'label': 'REFUND', 'score': 0.9999216794967651}],
#  [{'label': 'ACCOUNT', 'score': 0.999954104423523}],
#  [{'label': 'CANCEL', 'score': 0.999619722366333}],
#  [{'label': 'DELIVERY', 'score': 0.9997240900993347}],
#  [{'label': 'FEEDBACK', 'score': 0.999869704246521}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'DELIVERY', 'score': 0.999737560749054}],
#  [{'label': 'FEEDBACK', 'score': 0.999875545501709}],
#  [{'label': 'ACCOUNT', 'score': 0.9999555349349976}],
#  [{'label': 'ACCOUNT', 'score': 0.9999524354934692}],
#  [{'label': 'FEEDBACK', 'score': 0.999873161315918}],
#  [{'label': 'SHIPPING', 'score': 0.9998834133148193}],
#  [{'label': 'REFUND', 'score': 0.9999239444732666}],
#  [{'label': 'INVOICE', 'score': 0.9997090697288513}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'CONTACT', 'score': 0.9998594522476196}],
#  [{'label': 'DELIVERY', 'score': 0.9997429251670837}],
#  [{'label': 'REFUND', 'score': 0.999930739402771}],
#  [{'label': 'PAYMENT', 'score': 0.9999196529388428}],
#  [{'label': 'CANCEL', 'score': 0.9998148083686829}],
#  [{'label': 'PAYMENT', 'score': 0.9999240636825562}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'INVOICE', 'score': 0.9999125003814697}],
#  [{'label': 'FEEDBACK', 'score': 0.9998562335968018}],
#  [{'label': 'SHIPPING', 'score': 0.9998830556869507}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997919201850891}],
#  [{'label': 'INVOICE', 'score': 0.9999126195907593}],
#  [{'label': 'ORDER', 'score': 0.9999409914016724}],
#  [{'label': 'ORDER', 'score': 0.99993896484375}],
#  [{'label': 'SHIPPING', 'score': 0.9998849630355835}],
#  [{'label': 'DELIVERY', 'score': 0.9997460246086121}],
#  [{'label': 'CANCEL', 'score': 0.9998052716255188}],
#  [{'label': 'CONTACT', 'score': 0.9998856782913208}],
#  [{'label': 'DELIVERY', 'score': 0.9997180104255676}],
#  [{'label': 'REFUND', 'score': 0.9999279975891113}],
#  [{'label': 'ACCOUNT', 'score': 0.9999545812606812}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ACCOUNT', 'score': 0.9999431371688843}],
#  [{'label': 'REFUND', 'score': 0.9999068975448608}],
#  [{'label': 'PAYMENT', 'score': 0.9999250173568726}],
#  [{'label': 'REFUND', 'score': 0.9999256134033203}],
#  [{'label': 'INVOICE', 'score': 0.9999145269393921}],
#  [{'label': 'DELIVERY', 'score': 0.9997469782829285}],
#  [{'label': 'PAYMENT', 'score': 0.9999274015426636}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'INVOICE', 'score': 0.9999103546142578}],
#  [{'label': 'DELIVERY', 'score': 0.9997276663780212}],
#  [{'label': 'SHIPPING', 'score': 0.999881386756897}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'PAYMENT', 'score': 0.9999258518218994}],
#  [{'label': 'SHIPPING', 'score': 0.9998805522918701}],
#  [{'label': 'INVOICE', 'score': 0.9999169111251831}],
#  [{'label': 'INVOICE', 'score': 0.9999121427536011}],
#  [{'label': 'INVOICE', 'score': 0.9999114274978638}],
#  [{'label': 'ACCOUNT', 'score': 0.9999563694000244}],
#  [{'label': 'FEEDBACK', 'score': 0.9998551607131958}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'ACCOUNT', 'score': 0.9999517202377319}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'DELIVERY', 'score': 0.9997417330741882}],
#  [{'label': 'FEEDBACK', 'score': 0.9998601675033569}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'FEEDBACK', 'score': 0.9998376369476318}],
#  [{'label': 'ACCOUNT', 'score': 0.999955415725708}],
#  [{'label': 'ORDER', 'score': 0.9999403953552246}],
#  [{'label': 'PAYMENT', 'score': 0.9999262094497681}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997926354408264}],
#  [{'label': 'REFUND', 'score': 0.9999253749847412}],
#  [{'label': 'INVOICE', 'score': 0.9999071359634399}],
#  [{'label': 'PAYMENT', 'score': 0.9999268054962158}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'REFUND', 'score': 0.9999139308929443}],
#  [{'label': 'ACCOUNT', 'score': 0.9999580383300781}],
#  [{'label': 'FEEDBACK', 'score': 0.9998694658279419}],
#  [{'label': 'FEEDBACK', 'score': 0.9998794794082642}],
#  [{'label': 'ACCOUNT', 'score': 0.9999513626098633}],
#  [{'label': 'ORDER', 'score': 0.9999256134033203}],
#  [{'label': 'CONTACT', 'score': 0.9998962879180908}],
#  [{'label': 'REFUND', 'score': 0.9999179840087891}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'SHIPPING', 'score': 0.9998810291290283}],
#  [{'label': 'PAYMENT', 'score': 0.9999241828918457}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997935891151428}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'FEEDBACK', 'score': 0.9998767375946045}],
#  [{'label': 'DELIVERY', 'score': 0.9997425675392151}],
#  [{'label': 'ACCOUNT', 'score': 0.9999582767486572}],
#  [{'label': 'SHIPPING', 'score': 0.9998843669891357}],
#  [{'label': 'ACCOUNT', 'score': 0.9999529123306274}],
#  [{'label': 'ORDER', 'score': 0.9999420642852783}],
#  [{'label': 'ACCOUNT', 'score': 0.9999585151672363}],
#  [{'label': 'FEEDBACK', 'score': 0.9998761415481567}],
#  [{'label': 'DELIVERY', 'score': 0.9997438788414001}],
#  [{'label': 'ACCOUNT', 'score': 0.9999550580978394}],
#  [{'label': 'REFUND', 'score': 0.9998995065689087}],
#  [{'label': 'INVOICE', 'score': 0.9999122619628906}],
#  [{'label': 'DELIVERY', 'score': 0.999739944934845}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'INVOICE', 'score': 0.9999091625213623}],
#  [{'label': 'DELIVERY', 'score': 0.9997422099113464}],
#  [{'label': 'ORDER', 'score': 0.999932050704956}],
#  [{'label': 'CONTACT', 'score': 0.9998846054077148}],
#  [{'label': 'REFUND', 'score': 0.9999299049377441}],
#  [{'label': 'REFUND', 'score': 0.9999260902404785}],
#  [{'label': 'REFUND', 'score': 0.9999295473098755}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997879862785339}],
#  [{'label': 'REFUND', 'score': 0.9999105930328369}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'INVOICE', 'score': 0.9999082088470459}],
#  [{'label': 'ORDER', 'score': 0.9999397993087769}],
#  [{'label': 'CONTACT', 'score': 0.9998847246170044}],
#  [{'label': 'REFUND', 'score': 0.9999300241470337}],
#  [{'label': 'DELIVERY', 'score': 0.999743640422821}],
#  [{'label': 'ACCOUNT', 'score': 0.9999532699584961}],
#  [{'label': 'DELIVERY', 'score': 0.9997416138648987}],
#  [{'label': 'CANCEL', 'score': 0.9998169541358948}],
#  [{'label': 'CONTACT', 'score': 0.9998817443847656}],
#  [{'label': 'INVOICE', 'score': 0.9999083280563354}],
#  [{'label': 'REFUND', 'score': 0.9999191761016846}],
#  [{'label': 'SHIPPING', 'score': 0.9998857975006104}],
#  [{'label': 'ORDER', 'score': 0.9999209642410278}],
#  [{'label': 'FEEDBACK', 'score': 0.9998810291290283}],
#  [{'label': 'FEEDBACK', 'score': 0.9998688697814941}],
#  [{'label': 'ACCOUNT', 'score': 0.9999511241912842}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'SHIPPING', 'score': 0.9998817443847656}],
#  [{'label': 'SHIPPING', 'score': 0.9998787641525269}],
#  [{'label': 'ORDER', 'score': 0.9999411106109619}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'ACCOUNT', 'score': 0.9999566078186035}],
#  [{'label': 'ACCOUNT', 'score': 0.9999536275863647}],
#  [{'label': 'ORDER', 'score': 0.9999411106109619}],
#  [{'label': 'ORDER', 'score': 0.9999253749847412}],
#  [{'label': 'FEEDBACK', 'score': 0.9998606443405151}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'ORDER', 'score': 0.9999343156814575}],
#  [{'label': 'ACCOUNT', 'score': 0.999956488609314}],
#  [{'label': 'PAYMENT', 'score': 0.9999257326126099}],
#  [{'label': 'REFUND', 'score': 0.999931812286377}],
#  [{'label': 'REFUND', 'score': 0.9999197721481323}],
#  [{'label': 'ORDER', 'score': 0.9999370574951172}],
#  [{'label': 'REFUND', 'score': 0.9999309778213501}],
#  [{'label': 'REFUND', 'score': 0.9999110698699951}],
#  [{'label': 'FEEDBACK', 'score': 0.9998694658279419}],
#  [{'label': 'SHIPPING', 'score': 0.9998759031295776}],
#  [{'label': 'CONTACT', 'score': 0.9998860359191895}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'SHIPPING', 'score': 0.9998824596405029}],
#  [{'label': 'REFUND', 'score': 0.9999316930770874}],
#  [{'label': 'ACCOUNT', 'score': 0.9999566078186035}],
#  [{'label': 'CANCEL', 'score': 0.9998123049736023}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'CONTACT', 'score': 0.9998944997787476}],
#  [{'label': 'DELIVERY', 'score': 0.9997461438179016}],
#  [{'label': 'ORDER', 'score': 0.9999428987503052}],
#  [{'label': 'REFUND', 'score': 0.9999200105667114}],
#  [{'label': 'SHIPPING', 'score': 0.9998762607574463}],
#  [{'label': 'PAYMENT', 'score': 0.9999217987060547}],
#  [{'label': 'CANCEL', 'score': 0.9998117089271545}],
#  [{'label': 'DELIVERY', 'score': 0.9997387528419495}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'CONTACT', 'score': 0.9998952150344849}],
#  [{'label': 'REFUND', 'score': 0.9999136924743652}],
#  [{'label': 'INVOICE', 'score': 0.9999018907546997}],
#  [{'label': 'DELIVERY', 'score': 0.9997509121894836}],
#  [{'label': 'FEEDBACK', 'score': 0.9998655319213867}],
#  [{'label': 'CONTACT', 'score': 0.9998821020126343}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997919201850891}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'FEEDBACK', 'score': 0.9998646974563599}],
#  [{'label': 'REFUND', 'score': 0.9999058246612549}],
#  [{'label': 'ORDER', 'score': 0.9999415874481201}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'PAYMENT', 'score': 0.9999252557754517}],
#  [{'label': 'INVOICE', 'score': 0.9999114274978638}],
#  [{'label': 'FEEDBACK', 'score': 0.9998770952224731}],
#  [{'label': 'FEEDBACK', 'score': 0.9998623132705688}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'INVOICE', 'score': 0.9999171495437622}],
#  [{'label': 'REFUND', 'score': 0.9999102354049683}],
#  [{'label': 'ORDER', 'score': 0.9999357461929321}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'SHIPPING', 'score': 0.9998840093612671}],
#  [{'label': 'ORDER', 'score': 0.9999344348907471}],
#  [{'label': 'REFUND', 'score': 0.9999312162399292}],
#  [{'label': 'FEEDBACK', 'score': 0.9998704195022583}],
#  [{'label': 'FEEDBACK', 'score': 0.9998764991760254}],
#  [{'label': 'SHIPPING', 'score': 0.9998812675476074}],
#  [{'label': 'CONTACT', 'score': 0.999880313873291}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997918009757996}],
#  [{'label': 'CONTACT', 'score': 0.9998929500579834}],
#  [{'label': 'SHIPPING', 'score': 0.9998810291290283}],
#  [{'label': 'FEEDBACK', 'score': 0.9998729228973389}],
#  [{'label': 'REFUND', 'score': 0.999923825263977}],
#  [{'label': 'ACCOUNT', 'score': 0.9999552965164185}],
#  [{'label': 'FEEDBACK', 'score': 0.9998779296875}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'ACCOUNT', 'score': 0.9999521970748901}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'FEEDBACK', 'score': 0.9998733997344971}],
#  [{'label': 'ACCOUNT', 'score': 0.9999587535858154}],
#  [{'label': 'REFUND', 'score': 0.9999257326126099}],
#  [{'label': 'REFUND', 'score': 0.9999276399612427}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997929930686951}],
#  [{'label': 'SHIPPING', 'score': 0.9998811483383179}],
#  [{'label': 'REFUND', 'score': 0.9999303817749023}],
#  [{'label': 'FEEDBACK', 'score': 0.9998779296875}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997907280921936}],
#  [{'label': 'CANCEL', 'score': 0.9998083710670471}],
#  [{'label': 'PAYMENT', 'score': 0.9999262094497681}],
#  [{'label': 'SHIPPING', 'score': 0.9998798370361328}],
#  [{'label': 'PAYMENT', 'score': 0.9999245405197144}],
#  [{'label': 'FEEDBACK', 'score': 0.9998792409896851}],
#  [{'label': 'DELIVERY', 'score': 0.9997428059577942}],
#  [{'label': 'REFUND', 'score': 0.9999315738677979}],
#  [{'label': 'ACCOUNT', 'score': 0.9999502897262573}],
#  [{'label': 'DELIVERY', 'score': 0.9997472167015076}],
#  [{'label': 'ACCOUNT', 'score': 0.9999531507492065}],
#  [{'label': 'DELIVERY', 'score': 0.9997488856315613}],
#  [{'label': 'INVOICE', 'score': 0.9999114274978638}],
#  [{'label': 'SHIPPING', 'score': 0.9998838901519775}],
#  [{'label': 'REFUND', 'score': 0.9999203681945801}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'CONTACT', 'score': 0.99988853931427}],
#  [{'label': 'PAYMENT', 'score': 0.9999253749847412}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'ORDER', 'score': 0.9999299049377441}],
#  [{'label': 'ORDER', 'score': 0.9999294281005859}],
#  [{'label': 'CONTACT', 'score': 0.9998831748962402}],
#  [{'label': 'SHIPPING', 'score': 0.9998812675476074}],
#  [{'label': 'INVOICE', 'score': 0.9999104738235474}],
#  [{'label': 'ORDER', 'score': 0.9999197721481323}],
#  [{'label': 'ACCOUNT', 'score': 0.9999481439590454}],
#  [{'label': 'DELIVERY', 'score': 0.9997159838676453}],
#  [{'label': 'ACCOUNT', 'score': 0.999955415725708}],
#  [{'label': 'ACCOUNT', 'score': 0.9999524354934692}],
#  [{'label': 'FEEDBACK', 'score': 0.9998664855957031}],
#  [{'label': 'REFUND', 'score': 0.9999256134033203}],
#  [{'label': 'SHIPPING', 'score': 0.9998757839202881}],
#  [{'label': 'FEEDBACK', 'score': 0.9998512268066406}],
#  [{'label': 'FEEDBACK', 'score': 0.9998787641525269}],
#  [{'label': 'REFUND', 'score': 0.9999277591705322}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999284744262695}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'SHIPPING', 'score': 0.9998805522918701}],
#  [{'label': 'PAYMENT', 'score': 0.9999243021011353}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'ACCOUNT', 'score': 0.9999512434005737}],
#  [{'label': 'CONTACT', 'score': 0.9998834133148193}],
#  [{'label': 'FEEDBACK', 'score': 0.9998739957809448}],
#  [{'label': 'SHIPPING', 'score': 0.9998797178268433}],
#  [{'label': 'DELIVERY', 'score': 0.9997437596321106}],
#  [{'label': 'CONTACT', 'score': 0.9998574256896973}],
#  [{'label': 'INVOICE', 'score': 0.9999090433120728}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'FEEDBACK', 'score': 0.9998642206192017}],
#  [{'label': 'CONTACT', 'score': 0.9998618364334106}],
#  [{'label': 'ACCOUNT', 'score': 0.9999529123306274}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'CONTACT', 'score': 0.9998952150344849}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'INVOICE', 'score': 0.9999128580093384}],
#  [{'label': 'REFUND', 'score': 0.9999266862869263}],
#  [{'label': 'PAYMENT', 'score': 0.999915361404419}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'CANCEL', 'score': 0.9998214840888977}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'CANCEL', 'score': 0.9998146891593933}],
#  [{'label': 'REFUND', 'score': 0.9999103546142578}],
#  [{'label': 'CONTACT', 'score': 0.9998854398727417}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'SHIPPING', 'score': 0.9998824596405029}],
#  [{'label': 'SHIPPING', 'score': 0.9998815059661865}],
#  [{'label': 'ORDER', 'score': 0.9999154806137085}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'CONTACT', 'score': 0.9998849630355835}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ORDER', 'score': 0.9999397993087769}],
#  [{'label': 'REFUND', 'score': 0.999906063079834}],
#  [{'label': 'DELIVERY', 'score': 0.9997339844703674}],
#  [{'label': 'ORDER', 'score': 0.99993896484375}],
#  [{'label': 'DELIVERY', 'score': 0.9997410178184509}],
#  [{'label': 'FEEDBACK', 'score': 0.9998708963394165}],
#  [{'label': 'REFUND', 'score': 0.9999175071716309}],
#  [{'label': 'CANCEL', 'score': 0.9998063445091248}],
#  [{'label': 'INVOICE', 'score': 0.9999107122421265}],
#  [{'label': 'REFUND', 'score': 0.999932050704956}],
#  [{'label': 'ACCOUNT', 'score': 0.9999525547027588}],
#  [{'label': 'CONTACT', 'score': 0.999885082244873}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'INVOICE', 'score': 0.9999080896377563}],
#  [{'label': 'PAYMENT', 'score': 0.9999265670776367}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ACCOUNT', 'score': 0.9999550580978394}],
#  [{'label': 'SHIPPING', 'score': 0.9998723268508911}],
#  [{'label': 'ORDER', 'score': 0.9999270439147949}],
#  [{'label': 'INVOICE', 'score': 0.9999102354049683}],
#  [{'label': 'ACCOUNT', 'score': 0.9999544620513916}],
#  [{'label': 'CONTACT', 'score': 0.9998854398727417}],
#  [{'label': 'PAYMENT', 'score': 0.9999260902404785}],
#  [{'label': 'ACCOUNT', 'score': 0.9999551773071289}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'ACCOUNT', 'score': 0.9999551773071289}],
#  [{'label': 'DELIVERY', 'score': 0.9997467398643494}],
#  [{'label': 'INVOICE', 'score': 0.9999138116836548}],
#  [{'label': 'DELIVERY', 'score': 0.999722421169281}],
#  [{'label': 'ORDER', 'score': 0.9999421834945679}],
#  [{'label': 'ACCOUNT', 'score': 0.9999535083770752}],
#  [{'label': 'SHIPPING', 'score': 0.9998819828033447}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'ACCOUNT', 'score': 0.9999518394470215}],
#  [{'label': 'REFUND', 'score': 0.9999312162399292}],
#  [{'label': 'CONTACT', 'score': 0.9998917579650879}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'DELIVERY', 'score': 0.9997437596321106}],
#  [{'label': 'SHIPPING', 'score': 0.9998832941055298}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999206066131592}],
#  [{'label': 'PAYMENT', 'score': 0.9999256134033203}],
#  [{'label': 'FEEDBACK', 'score': 0.9998589754104614}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'FEEDBACK', 'score': 0.9998685121536255}],
#  [{'label': 'REFUND', 'score': 0.9999316930770874}],
#  [{'label': 'ORDER', 'score': 0.9999351501464844}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'INVOICE', 'score': 0.9999129772186279}],
#  [{'label': 'SHIPPING', 'score': 0.9998818635940552}],
#  [{'label': 'PAYMENT', 'score': 0.999923825263977}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'ACCOUNT', 'score': 0.9999557733535767}],
#  [{'label': 'FEEDBACK', 'score': 0.9998713731765747}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'ACCOUNT', 'score': 0.9999537467956543}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'ORDER', 'score': 0.999870777130127}],
#  [{'label': 'ACCOUNT', 'score': 0.9999582767486572}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ORDER', 'score': 0.9999397993087769}],
#  [{'label': 'CONTACT', 'score': 0.9998859167098999}],
#  [{'label': 'FEEDBACK', 'score': 0.9998406171798706}],
#  [{'label': 'CANCEL', 'score': 0.9998181462287903}],
#  [{'label': 'INVOICE', 'score': 0.9998958110809326}],
#  [{'label': 'PAYMENT', 'score': 0.9999217987060547}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'REFUND', 'score': 0.9999294281005859}],
#  [{'label': 'SHIPPING', 'score': 0.9998716115951538}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'FEEDBACK', 'score': 0.9998573064804077}],
#  [{'label': 'CANCEL', 'score': 0.9998087286949158}],
#  [{'label': 'ACCOUNT', 'score': 0.9999552965164185}],
#  [{'label': 'CONTACT', 'score': 0.9998857975006104}],
#  [{'label': 'REFUND', 'score': 0.9999290704727173}],
#  [{'label': 'CONTACT', 'score': 0.9998979568481445}],
#  [{'label': 'FEEDBACK', 'score': 0.9998708963394165}],
#  [{'label': 'FEEDBACK', 'score': 0.999875545501709}],
#  [{'label': 'ACCOUNT', 'score': 0.9999501705169678}],
#  [{'label': 'REFUND', 'score': 0.9999330043792725}],
#  [{'label': 'REFUND', 'score': 0.9999301433563232}],
#  [{'label': 'DELIVERY', 'score': 0.9997331500053406}],
#  [{'label': 'ACCOUNT', 'score': 0.9999556541442871}],
#  [{'label': 'REFUND', 'score': 0.9999065399169922}],
#  [{'label': 'INVOICE', 'score': 0.9997982382774353}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'SHIPPING', 'score': 0.9998821020126343}],
#  [{'label': 'ACCOUNT', 'score': 0.9999566078186035}],
#  [{'label': 'INVOICE', 'score': 0.9999140501022339}],
#  [{'label': 'ORDER', 'score': 0.9999409914016724}],
#  [{'label': 'CONTACT', 'score': 0.9998937845230103}],
#  [{'label': 'ORDER', 'score': 0.9999418258666992}],
#  [{'label': 'DELIVERY', 'score': 0.9997492432594299}],
#  [{'label': 'REFUND', 'score': 0.9999186992645264}],
#  [{'label': 'FEEDBACK', 'score': 0.9998791217803955}],
#  [{'label': 'REFUND', 'score': 0.9999018907546997}],
#  [{'label': 'INVOICE', 'score': 0.9998962879180908}],
#  [{'label': 'ACCOUNT', 'score': 0.9999583959579468}],
#  [{'label': 'INVOICE', 'score': 0.9999104738235474}],
#  [{'label': 'CONTACT', 'score': 0.9998795986175537}],
#  [{'label': 'ORDER', 'score': 0.9999423027038574}],
#  [{'label': 'CANCEL', 'score': 0.9998074173927307}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'ACCOUNT', 'score': 0.9999394416809082}],
#  [{'label': 'REFUND', 'score': 0.9999147653579712}],
#  [{'label': 'ORDER', 'score': 0.9999381303787231}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'INVOICE', 'score': 0.9999092817306519}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'ACCOUNT', 'score': 0.9999468326568604}],
#  [{'label': 'REFUND', 'score': 0.9999269247055054}],
#  [{'label': 'ACCOUNT', 'score': 0.9999558925628662}],
#  [{'label': 'REFUND', 'score': 0.9999189376831055}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'FEEDBACK', 'score': 0.9998767375946045}],
#  [{'label': 'INVOICE', 'score': 0.9999127388000488}],
#  [{'label': 'ACCOUNT', 'score': 0.999954342842102}],
#  [{'label': 'ACCOUNT', 'score': 0.9999535083770752}],
#  [{'label': 'ORDER', 'score': 0.9999415874481201}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.999552309513092}],
#  [{'label': 'ORDER', 'score': 0.9999270439147949}],
#  [{'label': 'INVOICE', 'score': 0.9999165534973145}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'FEEDBACK', 'score': 0.9998668432235718}],
#  [{'label': 'ORDER', 'score': 0.9999295473098755}],
#  [{'label': 'REFUND', 'score': 0.9999319314956665}],
#  [{'label': 'ORDER', 'score': 0.9999420642852783}],
#  [{'label': 'CONTACT', 'score': 0.9998853206634521}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999253749847412}],
#  [{'label': 'ACCOUNT', 'score': 0.9999536275863647}],
#  [{'label': 'PAYMENT', 'score': 0.999913215637207}],
#  [{'label': 'PAYMENT', 'score': 0.9999241828918457}],
#  [{'label': 'REFUND', 'score': 0.999920129776001}],
#  [{'label': 'ACCOUNT', 'score': 0.9999547004699707}],
#  [{'label': 'ACCOUNT', 'score': 0.9999217987060547}],
#  [{'label': 'ACCOUNT', 'score': 0.9999547004699707}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'ORDER', 'score': 0.9999396800994873}],
#  [{'label': 'ORDER', 'score': 0.9999141693115234}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'REFUND', 'score': 0.9999195337295532}],
#  [{'label': 'ACCOUNT', 'score': 0.9999547004699707}],
#  [{'label': 'ACCOUNT', 'score': 0.9999524354934692}],
#  [{'label': 'CONTACT', 'score': 0.9998795986175537}],
#  [{'label': 'ORDER', 'score': 0.9999409914016724}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'PAYMENT', 'score': 0.9999268054962158}],
#  [{'label': 'ACCOUNT', 'score': 0.9999580383300781}],
#  [{'label': 'ORDER', 'score': 0.9999229907989502}],
#  [{'label': 'CONTACT', 'score': 0.9998877048492432}],
#  [{'label': 'INVOICE', 'score': 0.9999092817306519}],
#  [{'label': 'FEEDBACK', 'score': 0.9998805522918701}],
#  [{'label': 'FEEDBACK', 'score': 0.9998708963394165}],
#  [{'label': 'SHIPPING', 'score': 0.9998821020126343}],
#  [{'label': 'FEEDBACK', 'score': 0.9998420476913452}],
#  [{'label': 'ORDER', 'score': 0.9999302625656128}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ORDER', 'score': 0.9999324083328247}],
#  [{'label': 'ORDER', 'score': 0.9999415874481201}],
#  [{'label': 'CONTACT', 'score': 0.999880313873291}],
#  [{'label': 'CONTACT', 'score': 0.9998842477798462}],
#  [{'label': 'INVOICE', 'score': 0.999910831451416}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'ORDER', 'score': 0.999942421913147}],
#  [{'label': 'ACCOUNT', 'score': 0.9999557733535767}],
#  [{'label': 'ACCOUNT', 'score': 0.9999558925628662}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'ORDER', 'score': 0.999941349029541}],
#  [{'label': 'CONTACT', 'score': 0.999886155128479}],
#  [{'label': 'CANCEL', 'score': 0.9998177886009216}],
#  [{'label': 'ACCOUNT', 'score': 0.9999545812606812}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.999789297580719}],
#  [{'label': 'FEEDBACK', 'score': 0.9998747110366821}],
#  [{'label': 'ACCOUNT', 'score': 0.9999502897262573}],
#  [{'label': 'ACCOUNT', 'score': 0.9999536275863647}],
#  [{'label': 'SHIPPING', 'score': 0.9998703002929688}],
#  [{'label': 'REFUND', 'score': 0.9999256134033203}],
#  [{'label': 'INVOICE', 'score': 0.9999059438705444}],
#  [{'label': 'ORDER', 'score': 0.999941349029541}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'ORDER', 'score': 0.9999277591705322}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997918009757996}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ORDER', 'score': 0.9999357461929321}],
#  [{'label': 'REFUND', 'score': 0.999911904335022}],
#  [{'label': 'SHIPPING', 'score': 0.9998739957809448}],
#  [{'label': 'ORDER', 'score': 0.999941349029541}],
#  [{'label': 'DELIVERY', 'score': 0.9997217059135437}],
#  [{'label': 'REFUND', 'score': 0.999925971031189}],
#  [{'label': 'CANCEL', 'score': 0.9998134970664978}],
#  [{'label': 'ACCOUNT', 'score': 0.9999496936798096}],
#  [{'label': 'DELIVERY', 'score': 0.9997449517250061}],
#  [{'label': 'ACCOUNT', 'score': 0.9999520778656006}],
#  [{'label': 'FEEDBACK', 'score': 0.9998722076416016}],
#  [{'label': 'REFUND', 'score': 0.999901533126831}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'ACCOUNT', 'score': 0.9999489784240723}],
#  [{'label': 'REFUND', 'score': 0.9999096393585205}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'SHIPPING', 'score': 0.9998788833618164}],
#  [{'label': 'CANCEL', 'score': 0.9998132586479187}],
#  [{'label': 'FEEDBACK', 'score': 0.9998735189437866}],
#  [{'label': 'ORDER', 'score': 0.9999344348907471}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'DELIVERY', 'score': 0.9997445940971375}],
#  [{'label': 'ACCOUNT', 'score': 0.9999504089355469}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'REFUND', 'score': 0.9999275207519531}],
#  [{'label': 'SHIPPING', 'score': 0.9998795986175537}],
#  [{'label': 'PAYMENT', 'score': 0.9999266862869263}],
#  [{'label': 'ORDER', 'score': 0.9999388456344604}],
#  [{'label': 'CONTACT', 'score': 0.9998855590820312}],
#  [{'label': 'INVOICE', 'score': 0.9999139308929443}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'INVOICE', 'score': 0.9998995065689087}],
#  [{'label': 'DELIVERY', 'score': 0.999739944934845}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'ORDER', 'score': 0.9999350309371948}],
#  [{'label': 'FEEDBACK', 'score': 0.9998675584793091}],
#  [{'label': 'INVOICE', 'score': 0.9999122619628906}],
#  [{'label': 'REFUND', 'score': 0.9999275207519531}],
#  [{'label': 'FEEDBACK', 'score': 0.9998718500137329}],
#  [{'label': 'REFUND', 'score': 0.9999051094055176}],
#  [{'label': 'REFUND', 'score': 0.9999276399612427}],
#  [{'label': 'REFUND', 'score': 0.9999196529388428}],
#  [{'label': 'ORDER', 'score': 0.9999315738677979}],
#  [{'label': 'REFUND', 'score': 0.9999302625656128}],
#  [{'label': 'PAYMENT', 'score': 0.9999258518218994}],
#  [{'label': 'CONTACT', 'score': 0.9998908042907715}],
#  [{'label': 'ORDER', 'score': 0.9999397993087769}],
#  [{'label': 'CONTACT', 'score': 0.999882698059082}],
#  [{'label': 'PAYMENT', 'score': 0.9999263286590576}],
#  [{'label': 'ACCOUNT', 'score': 0.9999490976333618}],
#  [{'label': 'INVOICE', 'score': 0.9999092817306519}],
#  [{'label': 'PAYMENT', 'score': 0.9999253749847412}],
#  [{'label': 'INVOICE', 'score': 0.9999101161956787}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'CONTACT', 'score': 0.9998857975006104}],
#  [{'label': 'FEEDBACK', 'score': 0.9998714923858643}],
#  [{'label': 'REFUND', 'score': 0.9999136924743652}],
#  [{'label': 'REFUND', 'score': 0.999919056892395}],
#  [{'label': 'SHIPPING', 'score': 0.9998688697814941}],
#  [{'label': 'REFUND', 'score': 0.9999232292175293}],
#  [{'label': 'PAYMENT', 'score': 0.9999257326126099}],
#  [{'label': 'REFUND', 'score': 0.9999293088912964}],
#  [{'label': 'ORDER', 'score': 0.9999336004257202}],
#  [{'label': 'CONTACT', 'score': 0.9998906850814819}],
#  [{'label': 'FEEDBACK', 'score': 0.9998732805252075}],
#  [{'label': 'CONTACT', 'score': 0.9998970031738281}],
#  [{'label': 'SHIPPING', 'score': 0.999883770942688}],
#  [{'label': 'REFUND', 'score': 0.9999308586120605}],
#  [{'label': 'ACCOUNT', 'score': 0.9999563694000244}],
#  [{'label': 'ACCOUNT', 'score': 0.9999539852142334}],
#  [{'label': 'PAYMENT', 'score': 0.9999247789382935}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'INVOICE', 'score': 0.9999030828475952}],
#  [{'label': 'INVOICE', 'score': 0.9999120235443115}],
#  [{'label': 'CONTACT', 'score': 0.9998949766159058}],
#  [{'label': 'CONTACT', 'score': 0.9998925924301147}],
#  [{'label': 'ACCOUNT', 'score': 0.9999544620513916}],
#  [{'label': 'DELIVERY', 'score': 0.999733030796051}],
#  [{'label': 'CONTACT', 'score': 0.9998688697814941}],
#  [{'label': 'DELIVERY', 'score': 0.9997448325157166}],
#  [{'label': 'SHIPPING', 'score': 0.9998797178268433}],
#  [{'label': 'FEEDBACK', 'score': 0.9998782873153687}],
#  [{'label': 'ACCOUNT', 'score': 0.9999521970748901}],
#  [{'label': 'FEEDBACK', 'score': 0.9998772144317627}],
#  [{'label': 'REFUND', 'score': 0.9999197721481323}],
#  [{'label': 'ORDER', 'score': 0.9999349117279053}],
#  [{'label': 'ACCOUNT', 'score': 0.9999521970748901}],
#  [{'label': 'REFUND', 'score': 0.9999221563339233}],
#  [{'label': 'REFUND', 'score': 0.9998916387557983}],
#  [{'label': 'PAYMENT', 'score': 0.9999264478683472}],
#  [{'label': 'ORDER', 'score': 0.9999423027038574}],
#  [{'label': 'ORDER', 'score': 0.9999412298202515}],
#  [{'label': 'ACCOUNT', 'score': 0.999956488609314}],
#  [{'label': 'DELIVERY', 'score': 0.9997442364692688}],
#  [{'label': 'PAYMENT', 'score': 0.9999251365661621}],
#  [{'label': 'CANCEL', 'score': 0.9998121857643127}],
#  [{'label': 'SHIPPING', 'score': 0.9998829364776611}],
#  [{'label': 'SHIPPING', 'score': 0.999880313873291}],
#  [{'label': 'SHIPPING', 'score': 0.9998774528503418}],
#  [{'label': 'ACCOUNT', 'score': 0.9999514818191528}],
#  [{'label': 'CONTACT', 'score': 0.9998924732208252}],
#  [{'label': 'DELIVERY', 'score': 0.999745786190033}],
#  [{'label': 'ACCOUNT', 'score': 0.9999535083770752}],
#  [{'label': 'CANCEL', 'score': 0.9998185038566589}],
#  [{'label': 'FEEDBACK', 'score': 0.9998692274093628}],
#  [{'label': 'ACCOUNT', 'score': 0.9999583959579468}],
#  [{'label': 'FEEDBACK', 'score': 0.999737560749054}],
#  [{'label': 'DELIVERY', 'score': 0.9997368454933167}],
#  [{'label': 'DELIVERY', 'score': 0.9997417330741882}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997923970222473}],
#  [{'label': 'REFUND', 'score': 0.999925971031189}],
#  [{'label': 'REFUND', 'score': 0.9999122619628906}],
#  [{'label': 'ORDER', 'score': 0.9999418258666992}],
#  [{'label': 'SHIPPING', 'score': 0.9994296431541443}],
#  [{'label': 'REFUND', 'score': 0.9999203681945801}],
#  [{'label': 'FEEDBACK', 'score': 0.9998712539672852}],
#  [{'label': 'FEEDBACK', 'score': 0.9998623132705688}],
#  [{'label': 'FEEDBACK', 'score': 0.999847412109375}],
#  [{'label': 'INVOICE', 'score': 0.9999077320098877}],
#  [{'label': 'PAYMENT', 'score': 0.9999268054962158}],
#  [{'label': 'ACCOUNT', 'score': 0.9997711777687073}],
#  [{'label': 'ACCOUNT', 'score': 0.9999542236328125}],
#  [{'label': 'REFUND', 'score': 0.9999169111251831}],
#  [{'label': 'CONTACT', 'score': 0.9998635053634644}],
#  [{'label': 'ORDER', 'score': 0.9999141693115234}],
#  [{'label': 'REFUND', 'score': 0.9999173879623413}],
#  [{'label': 'DELIVERY', 'score': 0.9997486472129822}],
#  [{'label': 'ORDER', 'score': 0.9999418258666992}],
#  [{'label': 'PAYMENT', 'score': 0.9999263286590576}],
#  [{'label': 'SHIPPING', 'score': 0.9998806715011597}],
#  [{'label': 'CONTACT', 'score': 0.9998836517333984}],
#  [{'label': 'ACCOUNT', 'score': 0.9999580383300781}],
#  [{'label': 'SHIPPING', 'score': 0.9998836517333984}],
#  [{'label': 'CONTACT', 'score': 0.9998805522918701}],
#  [{'label': 'INVOICE', 'score': 0.9999164342880249}],
#  [{'label': 'PAYMENT', 'score': 0.9999250173568726}],
#  [{'label': 'CONTACT', 'score': 0.9998869895935059}],
#  [{'label': 'PAYMENT', 'score': 0.999924898147583}],
#  [{'label': 'DELIVERY', 'score': 0.9997455477714539}],
#  [{'label': 'REFUND', 'score': 0.9999289512634277}],
#  [{'label': 'INVOICE', 'score': 0.9999122619628906}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997904896736145}],
#  [{'label': 'PAYMENT', 'score': 0.9999252557754517}],
#  [{'label': 'ORDER', 'score': 0.9999344348907471}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'CONTACT', 'score': 0.9998866319656372}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'REFUND', 'score': 0.9999122619628906}],
#  [{'label': 'PAYMENT', 'score': 0.9999262094497681}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'ORDER', 'score': 0.9999200105667114}],
#  [{'label': 'ACCOUNT', 'score': 0.9999587535858154}],
#  [{'label': 'SHIPPING', 'score': 0.9998867511749268}],
#  [{'label': 'SHIPPING', 'score': 0.9998810291290283}],
#  [{'label': 'CONTACT', 'score': 0.9998912811279297}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'FEEDBACK', 'score': 0.9998698234558105}],
#  [{'label': 'SHIPPING', 'score': 0.9998830556869507}],
#  [{'label': 'DELIVERY', 'score': 0.9997456669807434}],
#  [{'label': 'INVOICE', 'score': 0.9999122619628906}],
#  [{'label': 'CONTACT', 'score': 0.9998961687088013}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'CANCEL', 'score': 0.9998152852058411}],
#  [{'label': 'CONTACT', 'score': 0.9998526573181152}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'CANCEL', 'score': 0.9998125433921814}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997923970222473}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'FEEDBACK', 'score': 0.9998660087585449}],
#  [{'label': 'ORDER', 'score': 0.9999421834945679}],
#  [{'label': 'SHIPPING', 'score': 0.9998779296875}],
#  [{'label': 'REFUND', 'score': 0.9998819828033447}],
#  [{'label': 'SHIPPING', 'score': 0.999883770942688}],
#  [{'label': 'PAYMENT', 'score': 0.9999219179153442}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'CANCEL', 'score': 0.9998125433921814}],
#  [{'label': 'SHIPPING', 'score': 0.9998838901519775}],
#  [{'label': 'PAYMENT', 'score': 0.9999209642410278}],
#  [{'label': 'SHIPPING', 'score': 0.999881386756897}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997931122779846}],
#  [{'label': 'REFUND', 'score': 0.9999300241470337}],
#  [{'label': 'CANCEL', 'score': 0.9998189806938171}],
#  [{'label': 'CONTACT', 'score': 0.9996892213821411}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'CONTACT', 'score': 0.9998854398727417}],
#  [{'label': 'ORDER', 'score': 0.9999271631240845}],
#  [{'label': 'REFUND', 'score': 0.9999215602874756}],
#  [{'label': 'ORDER', 'score': 0.9999357461929321}],
#  [{'label': 'CONTACT', 'score': 0.9998925924301147}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'ORDER', 'score': 0.9999129772186279}],
#  [{'label': 'INVOICE', 'score': 0.9999115467071533}],
#  [{'label': 'ACCOUNT', 'score': 0.9999533891677856}],
#  [{'label': 'ACCOUNT', 'score': 0.9999411106109619}],
#  [{'label': 'DELIVERY', 'score': 0.9997391104698181}],
#  [{'label': 'CONTACT', 'score': 0.999884843826294}],
#  [{'label': 'ORDER', 'score': 0.9999401569366455}],
#  [{'label': 'SHIPPING', 'score': 0.9998782873153687}],
#  [{'label': 'ACCOUNT', 'score': 0.9999558925628662}],
#  [{'label': 'CONTACT', 'score': 0.9998809099197388}],
#  [{'label': 'SHIPPING', 'score': 0.9998780488967896}],
#  [{'label': 'SHIPPING', 'score': 0.9998795986175537}],
#  [{'label': 'CONTACT', 'score': 0.9998944997787476}],
#  [{'label': 'ORDER', 'score': 0.9999399185180664}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'ORDER', 'score': 0.9999401569366455}],
#  [{'label': 'ORDER', 'score': 0.9999061822891235}],
#  [{'label': 'INVOICE', 'score': 0.9999138116836548}],
#  [{'label': 'FEEDBACK', 'score': 0.999818742275238}],
#  [{'label': 'CONTACT', 'score': 0.9998811483383179}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'CONTACT', 'score': 0.9998984336853027}],
#  [{'label': 'DELIVERY', 'score': 0.9997473359107971}],
#  [{'label': 'CANCEL', 'score': 0.9998012185096741}],
#  [{'label': 'ORDER', 'score': 0.999941349029541}],
#  [{'label': 'PAYMENT', 'score': 0.999924898147583}],
#  [{'label': 'INVOICE', 'score': 0.9999053478240967}],
#  [{'label': 'FEEDBACK', 'score': 0.9998548030853271}],
#  [{'label': 'CANCEL', 'score': 0.9998096823692322}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'PAYMENT', 'score': 0.9999262094497681}],
#  [{'label': 'FEEDBACK', 'score': 0.9998692274093628}],
#  [{'label': 'PAYMENT', 'score': 0.9999223947525024}],
#  [{'label': 'CONTACT', 'score': 0.9998867511749268}],
#  [{'label': 'INVOICE', 'score': 0.9999089241027832}],
#  [{'label': 'ACCOUNT', 'score': 0.999954104423523}],
#  [{'label': 'REFUND', 'score': 0.9999167919158936}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'SHIPPING', 'score': 0.9998748302459717}],
#  [{'label': 'REFUND', 'score': 0.9999314546585083}],
#  [{'label': 'REFUND', 'score': 0.9999064207077026}],
#  [{'label': 'REFUND', 'score': 0.999925971031189}],
#  [{'label': 'FEEDBACK', 'score': 0.999874472618103}],
#  [{'label': 'REFUND', 'score': 0.9999222755432129}],
#  [{'label': 'ACCOUNT', 'score': 0.9999545812606812}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997888207435608}],
#  [{'label': 'INVOICE', 'score': 0.9999138116836548}],
#  [{'label': 'ACCOUNT', 'score': 0.9999370574951172}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'REFUND', 'score': 0.9999189376831055}],
#  [{'label': 'DELIVERY', 'score': 0.999747097492218}],
#  [{'label': 'SHIPPING', 'score': 0.9998818635940552}],
#  [{'label': 'FEEDBACK', 'score': 0.9998764991760254}],
#  [{'label': 'DELIVERY', 'score': 0.9997482895851135}],
#  [{'label': 'ORDER', 'score': 0.9999260902404785}],
#  [{'label': 'ACCOUNT', 'score': 0.999954104423523}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'DELIVERY', 'score': 0.9997425675392151}],
#  [{'label': 'DELIVERY', 'score': 0.9997438788414001}],
#  [{'label': 'INVOICE', 'score': 0.9999059438705444}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ACCOUNT', 'score': 0.9999537467956543}],
#  [{'label': 'DELIVERY', 'score': 0.9997429251670837}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'PAYMENT', 'score': 0.9999252557754517}],
#  [{'label': 'ORDER', 'score': 0.999936580657959}],
#  [{'label': 'FEEDBACK', 'score': 0.9998700618743896}],
#  [{'label': 'DELIVERY', 'score': 0.9997428059577942}],
#  [{'label': 'ACCOUNT', 'score': 0.9999544620513916}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'CONTACT', 'score': 0.9998799562454224}],
#  [{'label': 'DELIVERY', 'score': 0.9997417330741882}],
#  [{'label': 'REFUND', 'score': 0.9999063014984131}],
#  [{'label': 'INVOICE', 'score': 0.999911904335022}],
#  [{'label': 'CANCEL', 'score': 0.9997250437736511}],
#  [{'label': 'CONTACT', 'score': 0.9998939037322998}],
#  [{'label': 'ACCOUNT', 'score': 0.9999538660049438}],
#  [{'label': 'ORDER', 'score': 0.9999356269836426}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.999792754650116}],
#  [{'label': 'ORDER', 'score': 0.9999412298202515}],
#  [{'label': 'ORDER', 'score': 0.9999397993087769}],
#  [{'label': 'CONTACT', 'score': 0.9998849630355835}],
#  [{'label': 'CONTACT', 'score': 0.9998968839645386}],
#  [{'label': 'INVOICE', 'score': 0.9999130964279175}],
#  [{'label': 'INVOICE', 'score': 0.9999141693115234}],
#  [{'label': 'ACCOUNT', 'score': 0.9999517202377319}],
#  [{'label': 'REFUND', 'score': 0.9998999834060669}],
#  [{'label': 'SHIPPING', 'score': 0.9998815059661865}],
#  [{'label': 'INVOICE', 'score': 0.9999134540557861}],
#  [{'label': 'PAYMENT', 'score': 0.9999240636825562}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997898936271667}],
#  [{'label': 'FEEDBACK', 'score': 0.9998706579208374}],
#  [{'label': 'ORDER', 'score': 0.9999382495880127}],
#  [{'label': 'SHIPPING', 'score': 0.9998779296875}],
#  [{'label': 'REFUND', 'score': 0.9999278783798218}],
#  [{'label': 'SHIPPING', 'score': 0.999883770942688}],
#  [{'label': 'REFUND', 'score': 0.9999239444732666}],
#  [{'label': 'REFUND', 'score': 0.9999303817749023}],
#  [{'label': 'CONTACT', 'score': 0.9998862743377686}],
#  [{'label': 'PAYMENT', 'score': 0.9999241828918457}],
#  [{'label': 'REFUND', 'score': 0.9999147653579712}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'ACCOUNT', 'score': 0.9999505281448364}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997896552085876}],
#  [{'label': 'SHIPPING', 'score': 0.9998824596405029}],
#  [{'label': 'FEEDBACK', 'score': 0.9998749494552612}],
#  [{'label': 'REFUND', 'score': 0.9999301433563232}],
#  [{'label': 'SHIPPING', 'score': 0.9998779296875}],
#  [{'label': 'SHIPPING', 'score': 0.9998797178268433}],
#  [{'label': 'SHIPPING', 'score': 0.9998834133148193}],
#  [{'label': 'ACCOUNT', 'score': 0.999954104423523}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'INVOICE', 'score': 0.9999133348464966}],
#  [{'label': 'REFUND', 'score': 0.999908447265625}],
#  [{'label': 'ACCOUNT', 'score': 0.9999542236328125}],
#  [{'label': 'CONTACT', 'score': 0.9998871088027954}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'CANCEL', 'score': 0.9998136162757874}],
#  [{'label': 'PAYMENT', 'score': 0.9998868703842163}],
#  [{'label': 'INVOICE', 'score': 0.9999126195907593}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'ACCOUNT', 'score': 0.9999562501907349}],
#  [{'label': 'SHIPPING', 'score': 0.9998786449432373}],
#  [{'label': 'DELIVERY', 'score': 0.9997194409370422}],
#  [{'label': 'DELIVERY', 'score': 0.9997425675392151}],
# ...
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'ORDER', 'score': 0.9999403953552246}],
#  [{'label': 'ORDER', 'score': 0.9999353885650635}],
#  [{'label': 'SHIPPING', 'score': 0.9998840093612671}],
#  [{'label': 'PAYMENT', 'score': 0.9999277591705322}],
#  [{'label': 'ORDER', 'score': 0.9999421834945679}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997891783714294}],
#  [{'label': 'SHIPPING', 'score': 0.9998846054077148}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ACCOUNT', 'score': 0.9999562501907349}],
#  [{'label': 'CONTACT', 'score': 0.9998831748962402}],
#  [{'label': 'ORDER', 'score': 0.9999337196350098}],
#  [{'label': 'REFUND', 'score': 0.9999196529388428}],
#  [{'label': 'CONTACT', 'score': 0.9998972415924072}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'REFUND', 'score': 0.9999322891235352}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'REFUND', 'score': 0.9999326467514038}],
#  [{'label': 'SHIPPING', 'score': 0.9998757839202881}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997910857200623}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'ACCOUNT', 'score': 0.999957799911499}],
#  [{'label': 'REFUND', 'score': 0.9999059438705444}],
#  [{'label': 'FEEDBACK', 'score': 0.9998737573623657}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'DELIVERY', 'score': 0.999744713306427}],
#  [{'label': 'REFUND', 'score': 0.9999171495437622}],
#  [{'label': 'CONTACT', 'score': 0.9998836517333984}],
#  [{'label': 'ORDER', 'score': 0.9995573163032532}],
#  [{'label': 'INVOICE', 'score': 0.9999139308929443}],
#  [{'label': 'PAYMENT', 'score': 0.9999210834503174}],
#  [{'label': 'ACCOUNT', 'score': 0.9999566078186035}],
#  [{'label': 'SHIPPING', 'score': 0.9998842477798462}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'ORDER', 'score': 0.9999197721481323}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'ACCOUNT', 'score': 0.9999514818191528}],
#  [{'label': 'REFUND', 'score': 0.9999072551727295}],
#  [{'label': 'FEEDBACK', 'score': 0.9998441934585571}],
#  [{'label': 'FEEDBACK', 'score': 0.9998596906661987}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'ACCOUNT', 'score': 0.9999514818191528}],
#  [{'label': 'CANCEL', 'score': 0.9996387958526611}],
#  [{'label': 'FEEDBACK', 'score': 0.9998708963394165}],
#  [{'label': 'ORDER', 'score': 0.9999419450759888}],
#  [{'label': 'CANCEL', 'score': 0.999819815158844}],
#  [{'label': 'FEEDBACK', 'score': 0.9998596906661987}],
#  [{'label': 'ORDER', 'score': 0.9999418258666992}],
#  [{'label': 'FEEDBACK', 'score': 0.9998717308044434}],
#  [{'label': 'SHIPPING', 'score': 0.999885082244873}],
#  [{'label': 'DELIVERY', 'score': 0.9997392296791077}],
#  [{'label': 'ACCOUNT', 'score': 0.9999507665634155}],
#  [{'label': 'INVOICE', 'score': 0.9999165534973145}],
#  [{'label': 'CONTACT', 'score': 0.9998822212219238}],
#  [{'label': 'CONTACT', 'score': 0.9998883008956909}],
#  [{'label': 'REFUND', 'score': 0.9999078512191772}],
#  [{'label': 'REFUND', 'score': 0.9999265670776367}],
#  [{'label': 'FEEDBACK', 'score': 0.999859094619751}],
#  [{'label': 'ORDER', 'score': 0.9999411106109619}],
#  [{'label': 'CONTACT', 'score': 0.9998939037322998}],
#  [{'label': 'ORDER', 'score': 0.9999186992645264}],
#  [{'label': 'INVOICE', 'score': 0.9999134540557861}],
#  [{'label': 'ACCOUNT', 'score': 0.9999562501907349}],
#  [{'label': 'CONTACT', 'score': 0.9998878240585327}],
#  [{'label': 'PAYMENT', 'score': 0.9999244213104248}],
#  [{'label': 'SHIPPING', 'score': 0.999881386756897}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ACCOUNT', 'score': 0.9999480247497559}],
#  [{'label': 'ORDER', 'score': 0.999923825263977}],
#  [{'label': 'PAYMENT', 'score': 0.9999252557754517}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ORDER', 'score': 0.9999432563781738}],
#  [{'label': 'PAYMENT', 'score': 0.9998801946640015}],
#  [{'label': 'ACCOUNT', 'score': 0.9999516010284424}],
#  [{'label': 'ACCOUNT', 'score': 0.9999547004699707}],
#  [{'label': 'DELIVERY', 'score': 0.9997453093528748}],
#  [{'label': 'REFUND', 'score': 0.9999126195907593}],
#  [{'label': 'CANCEL', 'score': 0.9994968175888062}],
#  [{'label': 'ACCOUNT', 'score': 0.9999406337738037}],
#  [{'label': 'CANCEL', 'score': 0.9998127818107605}],
#  [{'label': 'SHIPPING', 'score': 0.9998807907104492}],
#  [{'label': 'INVOICE', 'score': 0.9999173879623413}],
#  [{'label': 'REFUND', 'score': 0.9999035596847534}],
#  [{'label': 'PAYMENT', 'score': 0.9999252557754517}],
#  [{'label': 'ORDER', 'score': 0.9999222755432129}],
#  [{'label': 'FEEDBACK', 'score': 0.9998754262924194}],
#  [{'label': 'FEEDBACK', 'score': 0.9998595714569092}],
#  [{'label': 'INVOICE', 'score': 0.9999023675918579}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'PAYMENT', 'score': 0.999925971031189}],
#  [{'label': 'SHIPPING', 'score': 0.9994162321090698}],
#  [{'label': 'FEEDBACK', 'score': 0.9998757839202881}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'CONTACT', 'score': 0.999884843826294}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'INVOICE', 'score': 0.9999127388000488}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'FEEDBACK', 'score': 0.9998607635498047}],
#  [{'label': 'INVOICE', 'score': 0.9999130964279175}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'ORDER', 'score': 0.9999417066574097}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997891783714294}],
#  [{'label': 'PAYMENT', 'score': 0.9999245405197144}],
#  [{'label': 'ORDER', 'score': 0.9999402761459351}],
#  [{'label': 'ORDER', 'score': 0.9999387264251709}],
#  [{'label': 'CANCEL', 'score': 0.9998084902763367}],
#  [{'label': 'SHIPPING', 'score': 0.9998815059661865}],
#  [{'label': 'DELIVERY', 'score': 0.9997331500053406}],
#  [{'label': 'ORDER', 'score': 0.9999411106109619}],
#  [{'label': 'ACCOUNT', 'score': 0.9999520778656006}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'CANCEL', 'score': 0.9998119473457336}],
#  [{'label': 'FEEDBACK', 'score': 0.9998596906661987}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'PAYMENT', 'score': 0.9999244213104248}],
#  [{'label': 'SHIPPING', 'score': 0.9998811483383179}],
#  [{'label': 'FEEDBACK', 'score': 0.9998773336410522}],
#  [{'label': 'ORDER', 'score': 0.999942421913147}],
#  [{'label': 'REFUND', 'score': 0.9999213218688965}],
#  [{'label': 'CONTACT', 'score': 0.9998886585235596}],
#  [{'label': 'FEEDBACK', 'score': 0.9998687505722046}],
#  [{'label': 'CANCEL', 'score': 0.9998123049736023}],
#  [{'label': 'ACCOUNT', 'score': 0.9999526739120483}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997932314872742}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997914433479309}],
#  [{'label': 'FEEDBACK', 'score': 0.9998749494552612}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'FEEDBACK', 'score': 0.9998773336410522}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999116659164429}],
#  [{'label': 'PAYMENT', 'score': 0.9999253749847412}],
#  [{'label': 'ACCOUNT', 'score': 0.9999557733535767}],
#  [{'label': 'REFUND', 'score': 0.9999053478240967}],
#  [{'label': 'ACCOUNT', 'score': 0.9999574422836304}],
#  [{'label': 'ACCOUNT', 'score': 0.9999579191207886}],
#  [{'label': 'DELIVERY', 'score': 0.9997449517250061}],
#  [{'label': 'FEEDBACK', 'score': 0.999872088432312}],
#  [{'label': 'REFUND', 'score': 0.9998070597648621}],
#  [{'label': 'FEEDBACK', 'score': 0.9998736381530762}],
#  [{'label': 'SHIPPING', 'score': 0.9998812675476074}],
#  [{'label': 'INVOICE', 'score': 0.9999152421951294}],
#  [{'label': 'CANCEL', 'score': 0.9998183846473694}],
#  [{'label': 'CONTACT', 'score': 0.9998866319656372}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999281167984009}],
#  [{'label': 'CANCEL', 'score': 0.9998164772987366}],
#  [{'label': 'PAYMENT', 'score': 0.9999269247055054}],
#  [{'label': 'SHIPPING', 'score': 0.999882698059082}],
#  [{'label': 'ORDER', 'score': 0.9999215602874756}],
#  [{'label': 'ORDER', 'score': 0.9999396800994873}],
#  [{'label': 'SHIPPING', 'score': 0.9994086027145386}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9994803071022034}],
#  [{'label': 'DELIVERY', 'score': 0.9997350573539734}],
#  [{'label': 'ACCOUNT', 'score': 0.9999535083770752}],
#  [{'label': 'REFUND', 'score': 0.999929666519165}],
#  [{'label': 'ACCOUNT', 'score': 0.9999526739120483}],
#  [{'label': 'ACCOUNT', 'score': 0.9999555349349976}],
#  [{'label': 'PAYMENT', 'score': 0.9998369216918945}],
#  [{'label': 'ACCOUNT', 'score': 0.9999526739120483}],
#  [{'label': 'DELIVERY', 'score': 0.9997493624687195}],
#  [{'label': 'INVOICE', 'score': 0.999910831451416}],
#  [{'label': 'DELIVERY', 'score': 0.9997482895851135}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'ORDER', 'score': 0.9999232292175293}],
#  [{'label': 'ACCOUNT', 'score': 0.9999568462371826}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'DELIVERY', 'score': 0.9997475743293762}],
#  [{'label': 'REFUND', 'score': 0.9999232292175293}],
#  [{'label': 'REFUND', 'score': 0.9999158382415771}],
#  [{'label': 'DELIVERY', 'score': 0.9997425675392151}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'ACCOUNT', 'score': 0.9999510049819946}],
#  [{'label': 'ACCOUNT', 'score': 0.9999548196792603}],
#  [{'label': 'FEEDBACK', 'score': 0.9998741149902344}],
#  [{'label': 'SHIPPING', 'score': 0.9998778104782104}],
#  [{'label': 'ORDER', 'score': 0.9999372959136963}],
#  [{'label': 'PAYMENT', 'score': 0.9999268054962158}],
#  [{'label': 'ACCOUNT', 'score': 0.9999487400054932}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'ORDER', 'score': 0.9999418258666992}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'REFUND', 'score': 0.9999203681945801}],
#  [{'label': 'CANCEL', 'score': 0.9998152852058411}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997839331626892}],
#  [{'label': 'DELIVERY', 'score': 0.9997468590736389}],
#  [{'label': 'ACCOUNT', 'score': 0.9999433755874634}],
#  [{'label': 'PAYMENT', 'score': 0.9999239444732666}],
#  [{'label': 'ACCOUNT', 'score': 0.9999567270278931}],
#  [{'label': 'ACCOUNT', 'score': 0.9999512434005737}],
#  [{'label': 'FEEDBACK', 'score': 0.9998733997344971}],
#  [{'label': 'ACCOUNT', 'score': 0.9999527931213379}],
#  [{'label': 'ORDER', 'score': 0.9999409914016724}],
#  [{'label': 'ORDER', 'score': 0.9999415874481201}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'INVOICE', 'score': 0.9999127388000488}],
#  [{'label': 'SHIPPING', 'score': 0.9998823404312134}],
#  [{'label': 'CONTACT', 'score': 0.9998784065246582}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'ACCOUNT', 'score': 0.99994957447052}],
#  [{'label': 'INVOICE', 'score': 0.9999158382415771}],
#  [{'label': 'SHIPPING', 'score': 0.9998784065246582}],
#  [{'label': 'REFUND', 'score': 0.9999262094497681}],
#  [{'label': 'REFUND', 'score': 0.9999293088912964}],
#  [{'label': 'ORDER', 'score': 0.9999376535415649}],
#  [{'label': 'ORDER', 'score': 0.9999401569366455}],
#  [{'label': 'DELIVERY', 'score': 0.9997385144233704}],
#  [{'label': 'ACCOUNT', 'score': 0.9999496936798096}],
#  [{'label': 'SHIPPING', 'score': 0.9998787641525269}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'ACCOUNT', 'score': 0.9999520778656006}],
#  [{'label': 'CONTACT', 'score': 0.9996813535690308}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.999790608882904}],
#  [{'label': 'ACCOUNT', 'score': 0.9999573230743408}],
#  [{'label': 'ACCOUNT', 'score': 0.9999547004699707}],
#  [{'label': 'PAYMENT', 'score': 0.9999247789382935}],
#  [{'label': 'ACCOUNT', 'score': 0.9999507665634155}],
#  [{'label': 'SHIPPING', 'score': 0.9998812675476074}],
#  [{'label': 'CANCEL', 'score': 0.9998154044151306}],
#  [{'label': 'ORDER', 'score': 0.9999406337738037}],
#  [{'label': 'DELIVERY', 'score': 0.9997345805168152}],
#  [{'label': 'INVOICE', 'score': 0.9999092817306519}],
#  [{'label': 'ORDER', 'score': 0.9999427795410156}],
#  [{'label': 'FEEDBACK', 'score': 0.9998726844787598}],
#  [{'label': 'CONTACT', 'score': 0.9998949766159058}],
#  [{'label': 'ORDER', 'score': 0.9999412298202515}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'CANCEL', 'score': 0.9996912479400635}],
#  [{'label': 'ACCOUNT', 'score': 0.9999570846557617}],
#  [{'label': 'ORDER', 'score': 0.9999405145645142}],
#  [{'label': 'ACCOUNT', 'score': 0.9999535083770752}],
#  [{'label': 'FEEDBACK', 'score': 0.9998738765716553}],
#  [{'label': 'REFUND', 'score': 0.9999202489852905}],
#  [{'label': 'SHIPPING', 'score': 0.9998778104782104}],
#  [{'label': 'CANCEL', 'score': 0.9998170733451843}],
#  [{'label': 'REFUND', 'score': 0.999916672706604}],
#  [{'label': 'DELIVERY', 'score': 0.9997472167015076}],
#  [{'label': 'ACCOUNT', 'score': 0.9999550580978394}],
#  [{'label': 'SHIPPING', 'score': 0.9998847246170044}],
#  [{'label': 'PAYMENT', 'score': 0.9999254941940308}],
#  [{'label': 'INVOICE', 'score': 0.9999091625213623}],
#  [{'label': 'ACCOUNT', 'score': 0.9999566078186035}],
#  [{'label': 'FEEDBACK', 'score': 0.9998561143875122}],
#  [{'label': 'SUBSCRIPTION', 'score': 0.9997890591621399}],
#  [{'label': 'INVOICE', 'score': 0.9999130964279175}],
#  [{'label': 'ORDER', 'score': 0.9999408721923828}],
#  [{'label': 'ACCOUNT', 'score': 0.9999581575393677}],
#  [{'label': 'CANCEL', 'score': 0.9998194575309753}],
#  [{'label': 'ORDER', 'score': 0.9999393224716187}],
#  [{'label': 'SHIPPING', 'score': 0.9998860359191895}],
#  [{'label': 'ORDER', 'score': 0.9999316930770874}],
#  [{'label': 'ACCOUNT', 'score': 0.9999569654464722}],
#  [{'label': 'REFUND', 'score': 0.9999316930770874}],
#  [{'label': 'ACCOUNT', 'score': 0.9999560117721558}],
#  [{'label': 'REFUND', 'score': 0.9999277591705322}],
#  [{'label': 'CONTACT', 'score': 0.9998941421508789}],
#  [{'label': 'REFUND', 'score': 0.9999266862869263}],
#  [{'label': 'ACCOUNT', 'score': 0.9999493360519409}],
#  [{'label': 'FEEDBACK', 'score': 0.9998761415481567}],
#  [{'label': 'PAYMENT', 'score': 0.9999212026596069}],
#  [{'label': 'REFUND', 'score': 0.9999308586120605}],
#  [{'label': 'ACCOUNT', 'score': 0.9999575614929199}],
#  [{'label': 'ACCOUNT', 'score': 0.999956488609314}],
#  [{'label': 'ORDER', 'score': 0.999940037727356}],
#  [{'label': 'CONTACT', 'score': 0.99988853931427}],
#  [{'label': 'ORDER', 'score': 0.9999414682388306}],
#  [{'label': 'CANCEL', 'score': 0.9998140931129456}],
#  [{'label': 'ACCOUNT', 'score': 0.9999418258666992}],
#  [{'label': 'PAYMENT', 'score': 0.9999237060546875}],
#  [{'label': 'ACCOUNT', 'score': 0.9999561309814453}],
#  [{'label': 'PAYMENT', 'score': 0.9999245405197144}],
#  [{'label': 'INVOICE', 'score': 0.9999065399169922}],
#  [{'label': 'CONTACT', 'score': 0.9998862743377686}],
#  [{'label': 'CONTACT', 'score': 0.9998959302902222}],
#  [{'label': 'CONTACT', 'score': 0.9998805522918701}],
#  [{'label': 'SHIPPING', 'score': 0.9998843669891357}],
#  [{'label': 'SHIPPING', 'score': 0.9998801946640015}],
#  [{'label': 'ACCOUNT', 'score': 0.9999576807022095}],
#  [{'label': 'ACCOUNT', 'score': 0.9999580383300781}],
#  [{'label': 'ORDER', 'score': 0.9999407529830933}],
#  [{'label': 'CONTACT', 'score': 0.9997370839118958}],
#  [{'label': 'SHIPPING', 'score': 0.9998840093612671}],
#  [{'label': 'ACCOUNT', 'score': 0.9999580383300781}],
#  [{'label': 'PAYMENT', 'score': 0.9999207258224487}],
#  [{'label': 'DELIVERY', 'score': 0.9997383952140808}],
#  [{'label': 'ORDER', 'score': 0.9999412298202515}],
#  [{'label': 'ACCOUNT', 'score': 0.9999572038650513}],
#  [{'label': 'INVOICE', 'score': 0.9999094009399414}],
#  [{'label': 'CANCEL', 'score': 0.9998058676719666}],
#  [{'label': 'SHIPPING', 'score': 0.9998767375946045}],
#  [{'label': 'ORDER', 'score': 0.9999387264251709}],
#  [{'label': 'ACCOUNT', 'score': 0.9999550580978394}]]

# %%
# classifications_test[0][0]['label']
# Out:
# 'CONTACT'

# %%
classifications_test_df = pd.DataFrame([{"label": cls[0]['label'], "score": cls[0]['score']} for cls in classifications_test])

# %%
classifications_test_df.head()
# Out:
#      label     score
# 0  CONTACT  0.999887
# 1  INVOICE  0.999898
# 2  PAYMENT  0.999918
# 3  CONTACT  0.999896
# 4  PAYMENT  0.999927

# %% [markdown]
# # **Calculating Accuracy for classification of test data from dataset**

# %%
print(compute_accuracy(convert_labels_2_ids(classifications_test_df['label']), convert_labels_2_ids(test_df["category"])))
# Out:
# {'accuracy': 0.9996279069767442}

# %%
navs_test = get_navs(test_df["instruction"])

# %%
# navs_test
# Out:
# [RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
# ...
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='SUBSCRIPTION', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='CANCEL', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='DELIVERY', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='INVOICE', function_call=None, similarity_score=None),
#  RouteChoice(name='ACCOUNT', function_call=None, similarity_score=None),
#  RouteChoice(name='ORDER', function_call=None, similarity_score=None),
#  RouteChoice(name='CONTACT', function_call=None, similarity_score=None),
#  RouteChoice(name='FEEDBACK', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='SHIPPING', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  RouteChoice(name='PAYMENT', function_call=None, similarity_score=None),
#  RouteChoice(name='REFUND', function_call=None, similarity_score=None),
#  ...]

# %%
df_navs_test = pd.DataFrame([{"NAV_Name": nav.name, "NAV_Similarity_Score": nav.similarity_score} for nav in navs_test])

# %% [markdown]
# # **Calculating Accuracy for Semantic router of test data from dataset**

# %%
print(compute_accuracy(convert_labels_2_ids(df_navs_test['NAV_Name']), convert_labels_2_ids(test_df["category"])))
# Out:
# {'accuracy': 0.9994418604651163}
